# %%
# !pip install numpy matplotlib pandas scikit-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris_dataset = load_iris()

# %%
iris_dataset.target<2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
xi = iris_dataset.data[iris_dataset.target<2]
yi = iris_dataset.target[iris_dataset.target<2]

# %%
xx = xi[:,2:3]
xy = xi[:,3:4]

# %%
plt.scatter(xx[yi == 0], xy[yi == 0], marker='o', c='blue')

plt.scatter(xx[yi == 1], xy[yi == 1], marker='x', c='red')

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3083/4107182760.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from model import LogisticRegression
model = LogisticRegression(n_iters=10000)

# %%
model._sigmoid([-100, -10, 0, 10, 100])
# Out:
# array([3.72007598e-44, 4.53978687e-05, 5.00000000e-01, 9.99954602e-01,
#        1.00000000e+00])

# %%
X = xi[:,2:4]

# %%
model.fit(X, yi)
# Out:
# Loss:  0.6931471805599436
#
# Loss:  0.3257932198244409
#
# Loss:  0.2121028728898019
#
# Loss:  0.1552348898302687
#
# Loss:  0.12205198527002263
#
# Loss:  0.10053859706980267
#
# Loss:  0.08552747212585446
#
# Loss:  0.0744797301677195
#
# Loss:  0.06601588004325672
#
# Loss:  0.05932623812336366
#
# Loss:  0.05390587645587992
#
# Loss:  0.049424220809233615
#
# Loss:  0.045656054875371985
#
# Loss:  0.04244277135992213
#
# Loss:  0.03966950191086601
#
# Loss:  0.03725104056919677
#
# Loss:  0.035122863149564504
#
# Loss:  0.03323521726631561
#
# Loss:  0.03154912639021451
#
# Loss:  0.03003362292246589
#
# Loss:  0.028663791390062504
#
# Loss:  0.02741935823650079
#
# Loss:  0.026283658180258275
#
# Loss:  0.025242864921928145
#
# Loss:  0.024285410603379184
#
# Loss:  0.023401542139248124
#
# Loss:  0.022582978210389536
#
# Loss:  0.02182264125184465
#
# Loss:  0.02111444598111317
#
# Loss:  0.020453131024011795
#
# Loss:  0.01983412372691765
#
# Loss:  0.019253430765641996
#
# ...

# %%
y_prid = model.predict(X)
y_prob = model.predict_proba(X)

# %%
plot_x = np.array([min(xi[:, 2]) - 1, max(xi[:, 2]) + 1])

w=model.w
b=model.b

plot_y = -(w[0] * plot_x + b) / w[1]

plt.plot(plot_x, plot_y, c='green', label='Decision Boundary')

xx = xi[:,2:3]
xy = xi[:,3:4]
plt.scatter(xx[yi == 0], xy[yi == 0], marker='o', c='blue')
plt.scatter(xx[yi == 1], xy[yi == 1], marker='x', c='red')

plt.legend()
plt.show()
